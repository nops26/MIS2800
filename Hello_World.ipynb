# %% [markdown]
# <a href="https://colab.research.google.com/github/nops26/MIS2800/blob/main/Hello_World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello world")
# Out:
# hello world

# %%
("mis is best!")
# Out:
# 'mis is best!'
